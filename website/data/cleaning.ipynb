# %% [markdown]
# ## Cleaning Gun Violence Archive Data
# ### Mass Shootings

# %%
import pandas as pd
import numpy as np

mass_df = pd.read_csv("gunviolencearchive_mass_shooting_all_years.csv")
mass_df.head(10)
# Out:
#    Incident ID      Incident Date          State       City Or County  \
# 0      3106715  December 31, 2024     California              Oakland
# 1      3107076  December 31, 2024    Mississippi              Natchez
# 2      3105091  December 30, 2024       New York                Bronx
# 3      3105154  December 30, 2024       New York            Rochester
# 4      3103855  December 28, 2024  West Virginia          Grantsville
# 5      3104385  December 28, 2024     California          Signal Hill
# 6      3103407  December 28, 2024      Louisiana             Vacherie
# 7      3102259  December 26, 2024        Georgia                Macon
# 8      3101897  December 25, 2024        Indiana         Indianapolis
# 9      3102234  December 25, 2024        Florida  Homestead (Naranja)
#
#                             Address  Victims Killed  Victims Injured  \
# 0            200 block of Second St               1                3
# ...

# %%
import dataframe_image as dfi

# %%
import os

os.makedirs('../recourses/img', exist_ok=True)
dfi.export(mass_df.head(10), '../recourses/img/tables/mass_raw_table.png', table_conversion='chrome')

# %%
cleaned_mass_df = mass_df.replace(np.nan, '', regex=True)
cleaned_mass_df.drop(columns=['Operations', 'Address'], inplace=True)
cleaned_mass_df['Incident Date'] = pd.to_datetime(cleaned_mass_df['Incident Date']).dt.date
cleaned_mass_df['State'] = cleaned_mass_df['State'].str.title()
cleaned_mass_df['City Or County'] = cleaned_mass_df['City Or County'].str.title()
cleaned_mass_df.head(10)

os.makedirs('../recourses/img', exist_ok=True)
dfi.export(cleaned_mass_df.head(10), '../recourses/img/tables/mass_cleaned_table.png', table_conversion='chrome')

# %% [markdown]
# ### School Shootings

# %%
school_df = pd.read_csv("gunviolencearchive_school_shooting.csv")
school_df.head(10)
os.makedirs('../recourses/img', exist_ok=True)
dfi.export(school_df.head(10), '../recourses/img/tables/school_raw_table.png', table_conversion='chrome')

# %%
cleaned_school_df = school_df
cleaned_school_df.drop(columns=['Operations', 'Address'], inplace=True)
cleaned_school_df['Incident Date'] = pd.to_datetime(cleaned_school_df['Incident Date']).dt.date
cleaned_school_df['State'] = cleaned_school_df['State'].str.title()
cleaned_school_df['City Or County'] = cleaned_school_df['City Or County'].str.title()
cleaned_school_df.head(10)

os.makedirs('../recourses/img', exist_ok=True)
dfi.export(cleaned_school_df.head(10), '../recourses/img/tables/school_cleaned_table.png', table_conversion='chrome')

# %% [markdown]
# ### Officer Involved Shootings

# %%
officer_df = pd.read_csv("gunviolencearchive_officer_involved_shooting.csv")
officer_df.head(10)
os.makedirs('../recourses/img', exist_ok=True)
dfi.export(officer_df.head(10), '../recourses/img/tables/officer_raw_table.png', table_conversion='chrome')

# %%
cleaned_officer_df = officer_df.drop(columns=['Operations', 'Address'])
cleaned_officer_df['Incident Date'] = pd.to_datetime(cleaned_officer_df['Incident Date']).dt.date
cleaned_officer_df['State'] = cleaned_officer_df['State'].str.title()
cleaned_officer_df['City Or County'] = cleaned_officer_df['City Or County'].str.title()
cleaned_officer_df.head(10)

os.makedirs('../recourses/img', exist_ok=True)
dfi.export(cleaned_officer_df.head(10), '../recourses/img/tables/officer_cleaned_table.png', table_conversion='chrome')

# %% [markdown]
# ### Accidential Injuries

# %%
acc_inj_df = pd.read_csv("gunviolencearchive_accidental_injuries.csv")
acc_inj_df.head(10)
os.makedirs('../recourses/img', exist_ok=True)
dfi.export(acc_inj_df.head(10), '../recourses/img/tables/acc_inj_raw_table.png', table_conversion='chrome')

# %%
cleaned_acc_inj_df = acc_inj_df.drop(columns=['Operations', 'Address'])
cleaned_acc_inj_df['Incident Date'] = pd.to_datetime(cleaned_acc_inj_df['Incident Date']).dt.date
cleaned_acc_inj_df['State'] = cleaned_acc_inj_df['State'].str.title()
cleaned_acc_inj_df['City Or County'] = cleaned_acc_inj_df['City Or County'].str.title()
cleaned_acc_inj_df.head(10)
os.makedirs('../recourses/img', exist_ok=True)
dfi.export(cleaned_acc_inj_df.head(10), '../recourses/img/tables/acc_inj_cleaned_table.png', table_conversion='chrome')

# %% [markdown]
# ### Accidental Deaths

# %%
acc_death_df = pd.read_csv("gunviolencearchive_accidental_deaths.csv")
acc_death_df.head(10)
os.makedirs('../recourses/img', exist_ok=True)
dfi.export(acc_death_df.head(10), '../recourses/img/tables/acc_death_raw_table.png', table_conversion='chrome')

# %%
cleaned_acc_death_df = acc_death_df.drop(columns=['Operations', 'Address'])
cleaned_acc_death_df['Incident Date'] = pd.to_datetime(cleaned_acc_death_df['Incident Date']).dt.date
cleaned_acc_death_df['State'] = cleaned_acc_death_df['State'].str.title()
cleaned_acc_death_df['City Or County'] = cleaned_acc_death_df['City Or County'].str.title()
cleaned_acc_death_df.head(10)
os.makedirs('../recourses/img', exist_ok=True)
dfi.export(cleaned_acc_death_df.head(10), '../recourses/img/tables/acc_death_cleaned_table.png', table_conversion='chrome')

# %% [markdown]
# ## EDA Gun Violence Archive
# ### Mass Shootings

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data = cleaned_mass_df, x='State', order = cleaned_mass_df['State'].value_counts().index, color='darkred')
plt.xticks(rotation=90)
plt.title('Number of Mass Shootings by State from Jan 2014 to Dec 2024')
plt.xlabel('State')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/mass_shootings_by_state.png')
plt.show()

# %%
# Number of Mass Shootings by Year
mass_by_year_df = cleaned_mass_df
mass_by_year_df['Incident Year'] = pd.to_datetime(mass_by_year_df['Incident Date']).dt.year
mass_by_year_df.head(10)

plt.figure(figsize=(10, 6))
sns.countplot(data = mass_by_year_df, x='Incident Year', color='darkred')
plt.title('Number of Mass Shootings by Year from Jan 2014 to Dec 2024')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/mass_shootings_by_year.png')
plt.show()

# %%
# pick the columns you care about
cols_of_interest = ["Victims Injured", "Victims Killed", "Suspects Killed", "Suspects Injured", "Suspects Arrested"]

# group by year and sum counts
yearly = mass_by_year_df.groupby("Incident Year")[cols_of_interest].sum().reset_index()

# reshape into long format for seaborn
yearly_melted = yearly.melt(id_vars="Incident Year", 
                            value_vars=cols_of_interest, 
                            var_name="Category", 
                            value_name="Count")

# plot
plt.figure(figsize=(10,6))
sns.barplot(data=yearly_melted, x="Incident Year", y="Count", hue="Category")
plt.title("Mass Shooting Victims and Suspects per Year")
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/mass_shootings_injury_killed_by_year.png')
plt.show()

# %% [markdown]
# ### School Shootings

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data = cleaned_school_df, x='State', order = cleaned_school_df['State'].value_counts().index, color='darkorange')
plt.xticks(rotation=90)
plt.title('Number of School Shootings by State from Jan 2014 to Dec 2024')
plt.xlabel('State')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/school_shootings_by_state.png')
plt.show()

# %%
# Number of Mass Shootings by Year
school_by_year_df = cleaned_school_df
school_by_year_df['Incident Year'] = pd.to_datetime(school_by_year_df['Incident Date']).dt.year
school_by_year_df.head(10)

plt.figure(figsize=(10, 6))
sns.countplot(data = school_by_year_df, x='Incident Year', color='darkorange')
plt.title('Number of School Shootings by Year from Jan 2014 to Dec 2024')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/school_shootings_by_year.png')
plt.show()

# %%
# pick the columns you care about
cols_of_interest = ["Victims Injured", "Victims Killed", "Suspects Killed", "Suspects Injured", "Suspects Arrested"]

# group by year and sum counts
yearly = school_by_year_df.groupby("Incident Year")[cols_of_interest].sum().reset_index()

# reshape into long format for seaborn
yearly_melted = yearly.melt(id_vars="Incident Year", 
                            value_vars=cols_of_interest, 
                            var_name="Category", 
                            value_name="Count")

# plot
plt.figure(figsize=(10,6))
sns.barplot(data=yearly_melted, x="Incident Year", y="Count", hue="Category")
plt.title("School Shooting Victims and Suspects per Year")
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/school_shootings_injury_killed_by_year.png')
plt.show()

# %% [markdown]
# ### Officer Involved

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data = cleaned_officer_df, x='State', order = cleaned_officer_df['State'].value_counts().index, color='darkgreen')
plt.xticks(rotation=90)
plt.title('Number of Officer Involved Shootings by State from Jan 2014 to Dec 2024')
plt.xlabel('State')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/officer_involved_by_state.png')
plt.show()

# %%
officer_by_year_df = cleaned_officer_df
officer_by_year_df['Incident Year'] = pd.to_datetime(officer_by_year_df['Incident Date']).dt.year
officer_by_year_df.head(10)

plt.figure(figsize=(10, 6))
sns.countplot(data = officer_by_year_df, x='Incident Year', color='darkgreen')
plt.title('Number of Officer Involved Shootings by Year from Jan 2014 to Dec 2024')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/officer_involved_by_year.png')
plt.show()

# %%
# pick the columns you care about
cols_of_interest = ["Victims Injured", "Victims Killed", "Suspects Killed", "Suspects Injured", "Suspects Arrested"]

# group by year and sum counts
yearly = officer_by_year_df.groupby("Incident Year")[cols_of_interest].sum().reset_index()

# reshape into long format for seaborn
yearly_melted = yearly.melt(id_vars="Incident Year", 
                            value_vars=cols_of_interest, 
                            var_name="Category", 
                            value_name="Count")

# plot
plt.figure(figsize=(10,6))
sns.barplot(data=yearly_melted, x="Incident Year", y="Count", hue="Category")
plt.title("Officer Involvement Victims and Suspects per Year")
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/officer_involved_injury_killed_by_year.png')
plt.show()

# %% [markdown]
# ### Accidental Injuries

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data = cleaned_acc_inj_df, x='State', order = cleaned_acc_inj_df['State'].value_counts().index, color='darkblue')
plt.xticks(rotation=90)
plt.title('Number of Accidental Injuries by State from Jan 2014 to Dec 2024')
plt.xlabel('State')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/acc_inj_by_state.png')
plt.show()

# %%
acc_inj_by_year_df = cleaned_acc_inj_df
acc_inj_by_year_df['Incident Year'] = pd.to_datetime(acc_inj_by_year_df['Incident Date']).dt.year
acc_inj_by_year_df.head(10)

plt.figure(figsize=(10, 6))
sns.countplot(data = acc_inj_by_year_df, x='Incident Year', color='darkblue')
plt.title('Number of Accidental Injuries by Year from Jan 2014 to Dec 2024')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/acc_inj_by_year.png')
plt.show()

# %%
# pick the columns you care about
cols_of_interest = ["Victims Injured", "Victims Killed", "Suspects Killed", "Suspects Injured", "Suspects Arrested"]

# group by year and sum counts
yearly = acc_inj_by_year_df.groupby("Incident Year")[cols_of_interest].sum().reset_index()

# reshape into long format for seaborn
yearly_melted = yearly.melt(id_vars="Incident Year", 
                            value_vars=cols_of_interest, 
                            var_name="Category", 
                            value_name="Count")

# plot
plt.figure(figsize=(10,6))
sns.barplot(data=yearly_melted, x="Incident Year", y="Count", hue="Category")
plt.title("Accidential Injuries Victims and Suspects per Year")
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/acc_inj_injury_killed_by_year.png')
plt.show()

# %% [markdown]
# ### Accidental Deaths

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data = cleaned_acc_death_df, x='State', order = cleaned_acc_death_df['State'].value_counts().index, color='purple')
plt.xticks(rotation=90)
plt.title('Number of Accidental Deaths by State from Jan 2014 to Dec 2024')
plt.xlabel('State')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/acc_death_by_state.png')
plt.show()

# %%
acc_death_by_year_df = cleaned_acc_death_df
acc_death_by_year_df['Incident Year'] = pd.to_datetime(acc_death_by_year_df['Incident Date']).dt.year
acc_death_by_year_df.head(10)

plt.figure(figsize=(10, 6))
sns.countplot(data = acc_death_by_year_df, x='Incident Year', color='purple')
plt.title('Number of Accidental Deaths by Year from Jan 2014 to Dec 2024')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/acc_death_by_year.png')
plt.show()

# %%
# pick the columns you care about
cols_of_interest = ["Victims Injured", "Victims Killed", "Suspects Killed", "Suspects Injured", "Suspects Arrested"]

# group by year and sum counts
yearly = acc_death_by_year_df.groupby("Incident Year")[cols_of_interest].sum().reset_index()

# reshape into long format for seaborn
yearly_melted = yearly.melt(id_vars="Incident Year", 
                            value_vars=cols_of_interest, 
                            var_name="Category", 
                            value_name="Count")

# plot
plt.figure(figsize=(10,6))
sns.barplot(data=yearly_melted, x="Incident Year", y="Count", hue="Category")
plt.title("Accidental Death Victims and Suspects per Year")
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.tight_layout()
plt.savefig('../recourses/img/plots/acc_death_injury_killed_by_year.png')
plt.show()
